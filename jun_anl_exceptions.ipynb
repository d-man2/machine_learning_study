# %% [markdown]
# # Исключения
# ## Домашняя работа

# %% [markdown]
# ### Вопросы по лекциям.

# %% [markdown]
# Как поймать вообще все ошибки, которые могут произойти?

# %% [markdown]
# **Ответ:**
# <p>Нужно поместить блок кода, в котором необходимо отловить ошибки, в "капсулу" try-except без указания имени класса ошибки (либо с указанием класса BaseException, так как он является родительским классом по умолчанию)</p>

# %% [markdown]
# Сколько раз подряд можно указывать except?

# %% [markdown]
# **Ответ:**
# <p>Сколько классов ошибок необходимо отловить, столько раз можно указывать except</p>

# %% [markdown]
# Вы хотите с помощью print вывести название ошибки в консоль, как это сделать?

# %% [markdown]
# **Ответ:**

# %%
try: 
    print(10/0) #code with error
except BaseException as exp:
    print(exp)
# Out:
# division by zero

# %% [markdown]
# Вы хотите с помощью print вывести параметры ошибки в консоль, как это сделать?

# %% [markdown]
# **Ответ:**

# %%
try: 
    print(10/0) #code with error
except BaseException as exp:
    print(exp.args)
# Out:
# ('division by zero',)

# %% [markdown]
# Что такое DeprecationWarning?

# %% [markdown]
# **Ответ:**
# <p>Используется для предупреждения о том, что часть используемого функционала (функция/процедура) устарела, и нужно переходить на новый функционал</p>

# %% [markdown]
# ### Разминочные задания.
# <br>
#
# Вам даны две функции. Поисследуйте, какие ошибки могут возникнуть при их реализации. Обработайте эти ошибки.

# %%
def div():
    for i in range(2):
        try:
            x = int(input("enter a number: "))
            y = int(input("enter another number: "))
            print(x, '/', y, '=', x/y)
        except ZeroDivisionError as exp1:
            print(f'Catch Error: {exp1}, error args: {exp1.args}')
        except ValueError as exp2:
            print(f'Catch Error: {exp2}, error args: {exp2.args}, try another')
        except BaseException as exp3:
            print(f'Catch Strange Error: {exp3}, error args: {exp3.args}, try another')

# %%
def sumOfPairs(L1, L2):
    sum = 0
    sumOfPairs = []
    for i in range(len(L1)):
        try:
            sumOfPairs.append(L1[i]+L2[i])
        except TypeError as exp1:
            print(f'Catch Error: {exp1}, error args: {exp1.args}')
            continue
        except BaseException as exp2:
            print(f'Catch Strange Error: {exp2}, error args: {exp2.args}')
        except IndexError as exp3:
            print(f'Catch Error: {exp3}, error args: {exp3.args}')

    print("sumOfPairs = ", sumOfPairs)

# %%
div_ = div()
# Out:
# enter a number:
# Catch Error: invalid literal for int() with base 10: '', error args: ("invalid literal for int() with base 10: ''",), try another
# enter a number: 12
# enter another number: df
# Catch Error: invalid literal for int() with base 10: 'df', error args: ("invalid literal for int() with base 10: 'df'",), try another

# %%
list1 = [1, 2, 3, 4, 7]
List2 = [1, 2, 'asd', 0]
sumOfPairs_ = sumOfPairs(list1, List2)
# Out:
# Catch Error: unsupported operand type(s) for +: 'int' and 'str', error args: ("unsupported operand type(s) for +: 'int' and 'str'",)
# Catch Strange Error: list index out of range, error args: ('list index out of range',)
# sumOfPairs =  [2, 4, 4]

# %% [markdown]
# ### Задание 1.
#
# Есть файл с протоколом регистраций пользователей на сайте (registrations.txt).<br>
# Каждая строка содержит информацию о имени, электронной почте и возрасте человека. <br><br>
#
#
# Надо проверить данные из файла, для каждой строки:
#  - присутсвуют все три поля
#  - поле имени содержит только буквы
#  - поле email содержит @ и .
#  - поле возраст является числом от 10 до 99<br>
#
# В результате проверки нужно сформировать два файла
#  - registrations_good.log для правильных данных, записывать строки как есть
# - registrations_bad.log для ошибочных, записывать строку и вид ошибки.<br>
#
# Для валидации строки данных написать метод, который может выкидывать исключения:
#  - НЕ присутсвуют все три поля: ValueError
#  - поле имени содержит НЕ только буквы: NotNameError (кастомное исключение)
#  - поле email НЕ содержит @ и .(точку): NotEmailError (кастомное исключение)
#  - поле возраст НЕ является числом от 10 до 99: ValueError
# Вызов метода обернуть в try-except.

# %%
import os.path as path

class NotNameError(Exception):
    def __init__ (self, text):
        self.text = text

class NotEmailError(Exception):
    def __init__ (self, text):
        self.text = text
    
def write_row_in_file(file_name=None, row=None):
    if path.isfile(file_name):
        file_good_reg = open(file_name, 'a')
        file_good_reg.write(row)
        file_good_reg.close()
    else:
        file_good_reg = open(file_name, 'w')
        file_good_reg.write(row)
        file_good_reg.close()
    
def process_file(input_file_name=None, output_positive_file_name=None, output_negative_file_name=None):  
    
    with open(input_file_name, 'r') as file:
        for row in file: 
            try:
                name, email, age = row.split(' ')
                age = age.rstrip()
                if name.isalpha() == False:
                    raise NotNameError('Name field has numbers!')

                if email.find('.') == -1 or  email.find('@') == -1:
                    raise NotEmailError('E-mail filed is not correct!')

                if  (int(age) < 10 or int(age) > 99) or age.isdigit() == False:
                    raise ValueError('Age field is not digit or not between 10-99!')

                write_row_in_file(file_name=output_positive_file_name, row=row)

            except ValueError as exp1:
                print(f'Catch ValueError: {exp1}')
                row = 'ValueError: ' + row 
                write_row_in_file(file_name=output_negative_file_name, row=row)

            except NotNameError as exp2:
                print(f'Catch NotNameError: {exp2}')
                row='NotNameError: '+ row
                write_row_in_file(file_name=output_negative_file_name, row=row)

            except NotEmailError as exp3:
                print(f'Catch NotEmailError: {exp3}')
                row='NotEmailError: '+ row
                write_row_in_file(file_name=output_negative_file_name, row=row)

# %%
process_file(input_file_name='registrations_.txt',
             output_positive_file_name='registrations_good.log',
             output_negative_file_name='registrations_bad.log')
# Out:
# Catch NotNameError: Name field has numbers!
# Catch NotEmailError: E-mail filed is not correct!
# Catch NotEmailError: E-mail filed is not correct!
# Catch ValueError: Age field is not digit or not between 10-99!
# Catch ValueError: Age field is not digit or not between 10-99!
# Catch NotEmailError: E-mail filed is not correct!
# Catch ValueError: Age field is not digit or not between 10-99!
# Catch ValueError: Age field is not digit or not between 10-99!
# Catch NotEmailError: E-mail filed is not correct!
# Catch NotNameError: Name field has numbers!
# Catch ValueError: Age field is not digit or not between 10-99!
# Catch ValueError: Age field is not digit or not between 10-99!
# Catch NotNameError: Name field has numbers!
# Catch NotEmailError: E-mail filed is not correct!
# Catch NotEmailError: E-mail filed is not correct!
# Catch ValueError: Age field is not digit or not between 10-99!
# Catch NotNameError: Name field has numbers!
# ...

# %%
class NotNameError(Exception):
    pass


class NotEmailError(Exception):
    pass


class LogFilter:

    def run(self, file_name):
        with open('registrations_good.log', 'w') as self.good_log:
            with open('registrations_bad.log', 'w') as self.bad_log:
                self._proceed_file(file_name)

    def _proceed_file(self, file_name):
        with open(file_name, 'r') as ff:
            for line in ff:
                self._proceed_line(line)

    def _proceed_line(self, line):
        try:
            self._check_line(line)
        except ValueError as exc:
            message = exc.args[0]
            if 'not enough values to unpack' in message:
                message = 'Неполные данные'
            elif 'invalid literal for int' in message:
                message = 'Возраст не является числом'
            self.bad_log.write(f'{line[:-1]} - {message}\n')
        except NotNameError:
            self.bad_log.write(line[:-1] + ' - Это не имя' + '\n')
        except NotEmailError:
            self.bad_log.write(line[:-1] + ' - Это не email' + '\n')
        else:
            self.good_log.write(line)

    def _check_line(self, line):
        name, email, age = line.split(' ')
        if not name.isalpha():
            raise NotNameError()
        if '@' not in email or '.' not in email:
            raise NotEmailError()
        if not 10 <= int(age) <= 99:
            raise ValueError('Age not in 10..99 range')


flt = LogFilter()
flt.run(file_name='registrations.txt')
